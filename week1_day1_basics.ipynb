# %% [markdown]
# <a href="https://colab.research.google.com/github/rounak8367/AI_ML_Gene_Project/blob/main/week1_day1_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
a = [1,2,3,4,5]
print(sum(a))

# poem
poem = """Here is my poem
in multiple lines,
which I want to show."""
print(poem)
# Out:
# Hello, World!
# 15
# Here is my poem
# in multiple lines,
# which I want to show.

# %% [markdown]
# # Basics

# %%
print("hello i am rounak an young engineer who is willing to change his life")
#
# Out:
# hello i am rounak an young engineer who is willing to change his life

# %%
name ="Rounak"
age = "23"
city ="dumka"
goal ="ai/ml gene project"
print("name:",name)
print("age:",age)
print("city:",city)
print("goal:",goal)
# Out:
# name: Rounak
# age: 23
# city: dumka
# goal: ai/ml gene project

# %% [markdown]
# # variables

# %%
poem = """Here is my poem
in multiple lines,
which I want to show."""
print(poem)

# new program
# 🧠 Week 1 - Day 1: Python Basics
# Author: Kumar Rounak
# Date: 5 Nov 2025

# Let's start with the simplest thing:
print("Hello, World! I'm Rounak, and Beast Mode is ON 💪🔥")

# Variables
name = "Rounak"
age = 23
goal = "To master AI/ML and build NutrIGene AI"

print("Name:", name)
print("Age:", age)
print("Goal:", goal)

# Data types
integer_example = 10
float_example = 3.14
string_example = "Python is powerful"
boolean_example = True

print("Integer:", integer_example)
print("Float:", float_example)
print("String:", string_example)
print("Boolean:", boolean_example)

# Simple math operations
a = 10
b = 3
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Remainder:", a % b)

# Input and output
user_name = input("What's your name? ")
print("Nice to meet you,", user_name)


# first program
print("hello! my name is rounak ")
print("soon i will be complete my project")
# Out:
# Here is my poem
# in multiple lines,
# which I want to show.
# Hello, World! I'm Rounak, and Beast Mode is ON 💪🔥
# Name: Rounak
# Age: 23
# Goal: To master AI/ML and build NutrIGene AI
# Integer: 10
# Float: 3.14
# String: Python is powerful
# Boolean: True
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Remainder: 1
# What's your name? rounak
# Nice to meet you, rounak
# hello! my name is rounak
# soon i will be complete my project
